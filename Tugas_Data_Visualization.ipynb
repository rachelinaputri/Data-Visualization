# %% [markdown]
# <a href="https://colab.research.google.com/github/rachelinaputri/Data-Visualization/blob/main/Tugas_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Rachelina Putri Arta Saragih
#
# NIM  : 201012320020

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/epl-goalScorer(20-21).csv")

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    522 non-null    object
#  1   id            514 non-null    float64
#  2   player_name   514 non-null    object
#  3   games         514 non-null    float64
#  4   time          514 non-null    float64
#  5   goals         514 non-null    float64
#  6   xG            514 non-null    float64
#  7   assists       514 non-null    float64
#  8   xA            514 non-null    float64
#  9   shots         514 non-null    float64
#  10  key_passes    514 non-null    float64
#  11  yellow_cards  514 non-null    float64
#  12  red_cards     514 non-null    float64
#  13  position      514 non-null    object
#  14  team_title    514 non-null    object
#  15  npg           514 non-null    float64
#  16  npxG          514 non-null    float64
#  17  xGChain       514 non-null    float64
#  18  xGBuildup;    514 non-null    object
# dtypes: float64(14), object(5)
# memory usage: 77.6+ KB
# None

# %%
print(df.head())
# Out:
#   Unnamed: 0      id      player_name  games    time  goals         xG  \
# 0          0   647.0       Harry Kane   35.0  3097.0   23.0  22.174859
# 1          1  1250.0    Mohamed Salah   37.0  3085.0   22.0  20.250847
# 2          2  1228.0  Bruno Fernandes   37.0  3117.0   18.0  16.019454
# 3          3   453.0    Son Heung-Min   37.0  3139.0   17.0  11.023287
# 4          4   822.0  Patrick Bamford   38.0  3085.0   17.0  18.401863
#
#    assists         xA  shots  key_passes  yellow_cards  red_cards position  \
# 0     14.0   7.577094  138.0        49.0           1.0        0.0        F
# 1      5.0   6.528526  126.0        55.0           0.0        0.0    F M S
# 2     12.0  11.474996  121.0        95.0           6.0        0.0      M S
# 3     10.0   9.512992   68.0        75.0           0.0        0.0    F M S
# 4      7.0   3.782247  107.0        30.0           3.0        0.0      F S
#
#           team_title   npg       npxG    xGChain          xGBuildup;
# 0          Tottenham  19.0  19.130183  24.995648  4.451256847940385;
# 1          Liverpool  16.0  15.683834  28.968234  9.800235655158758;
# 2  Manchester United   9.0   8.407840  26.911412  11.93228487111628;
# 3          Tottenham  16.0  10.262118  20.671916  6.608751138672233;
# 4              Leeds  15.0  16.879525  23.394953  4.131795546039939;

# %%
print(df.describe())
# Out:
#                 id       games         time       goals          xG  \
# count   514.000000  514.000000   514.000000  514.000000  514.000000
# mean   4405.387160   19.620623  1420.984436    1.856031    1.997008
# std    3283.182563   11.682864  1038.137256    3.349477    3.336931
# min      65.000000    1.000000     1.000000    0.000000    0.000000
# 25%     842.250000    9.250000   443.000000    0.000000    0.074575
# 50%    4892.000000   21.000000  1342.000000    1.000000    0.734485
# 75%    7696.250000   30.000000  2340.000000    2.000000    2.020353
# max    9552.000000   38.000000  3420.000000   23.000000   22.174859
#
#           assists          xA       shots  key_passes  yellow_cards  \
# count  514.000000  514.000000  514.000000  514.000000    514.000000
# mean     1.301556    1.378486   17.338521   12.974708      2.073930
# std      2.093459    1.894887   21.674857   16.221341      2.215131
# min      0.000000    0.000000    0.000000    0.000000      0.000000
# 25%      0.000000    0.047035    2.000000    1.000000      0.000000
# 50%      0.000000    0.676772   10.000000    7.000000      2.000000
# 75%      2.000000    2.058012   23.000000   19.000000      3.000000
# max     14.000000   11.474996  138.000000   95.000000     12.000000
#
#         red_cards         npg        npxG     xGChain
# count  514.000000  514.000000  514.000000  514.000000
# mean     0.093385    1.659533    1.816342    5.664975
# std      0.297873    2.914446    2.947395    5.632832
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.074575    1.186190
# 50%      0.000000    0.000000    0.701733    4.210836
# 75%      0.000000    2.000000    1.914520    8.363743
# max      2.000000   19.000000   19.130183   28.968234

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'id', 'player_name', 'games', 'time', 'goals', 'xG',
#        'assists', 'xA', 'shots', 'key_passes', 'yellow_cards', 'red_cards',
#        'position', 'team_title', 'npg', 'npxG', 'xGChain', 'xGBuildup;'],
#       dtype='object')

# %%
# Menghitung jumlah gol, durasi bermain, dan assist
total_goals = df['goals'].sum()
total_playing_time = df['time'].sum()
total_assists = df['assists'].sum()
print("Total goals:", total_goals)
print("Total Minutes Played:", total_playing_time)
print("Total Assists:", total_assists)
# Out:
# Total goals: 954.0
# Total Minutes Played: 730386.0
# Total Assists: 669.0

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['goals'])
plt.title('Boxplot of Goals')
plt.show()

# %%
Q1 = df['goals'].quantile(0.25)
Q3 = df['goals'].quantile(0.75)
IQR = Q3 - Q1

lower_fence = Q1 - 1.5 * IQR
upper_fence = Q3 + 1.5 * IQR

outliers = df[(df['goals'] < lower_fence) | (df['goals'] > upper_fence)]
print("Outliers based on Tukey's fences for goals:")
print(outliers)
# Out:
# Outliers based on Tukey's fences for goals:
#    Unnamed: 0      id                player_name  games    time  goals  \
# 0           0   647.0                 Harry Kane   35.0  3097.0   23.0
# 1           1  1250.0              Mohamed Salah   37.0  3085.0   22.0
# 2           2  1228.0            Bruno Fernandes   37.0  3117.0   18.0
# 3           3   453.0              Son Heung-Min   37.0  3139.0   17.0
# 4           4   822.0            Patrick Bamford   38.0  3085.0   17.0
# 5           5  5555.0      Dominic Calvert-Lewin   32.0  2788.0   16.0
# 6           6   755.0                Jamie Vardy   34.0  2848.0   15.0
# 7           7  8865.0              Ollie Watkins   37.0  3330.0   14.0
# 8           8   314.0             Ilkay Gündogan   28.0  2033.0   13.0
# 9           9  3277.0        Alexandre Lacazette   30.0  1928.0   13.0
# 10         10   468.0              Callum Wilson   26.0  2079.0   12.0
# 11         11   620.0          Kelechi Iheanacho   25.0  1452.0   12.0
# 12         12   986.0                 Danny Ings   28.0  2115.0   12.0
# 13         13  4456.0                 Chris Wood   32.0  2675.0   12.0
# 14         14   522.0              Wilfried Zaha   30.0  2615.0   11.0
# 15         15   556.0            Marcus Rashford   37.0  2941.0   11.0
# 16         16   838.0                 Sadio Mané   35.0  2805.0   11.0
# 17         17  2251.0                Gareth Bale   20.0   909.0   11.0
# 44    F M S                 Leeds   7.0   5.755642  10.815974
# 45    F M S               Everton   6.0   9.666103  15.678683
# 46    F M S       Manchester City   7.0   5.728708   9.768891
# 47    F M S     Manchester United   7.0   6.975748  14.031833
# 48    F M S      Sheffield United   7.0   7.383084   9.682009
# 49    F M S               Chelsea   6.0  13.432796  20.533463
# 50    F M S              Brighton   6.0   6.619249  10.265667
# 51    F M S           Aston Villa   6.0   5.192684  17.487469
# 52      F S               Chelsea   6.0   6.189151   7.901170
# 53    F M S               Everton   3.0   3.336608   8.377621
# 54    F M S               Everton   6.0   3.363538  12.033005
# 55      M S             Leicester   4.0   2.645866  18.975342
# 56    F M S               Chelsea   5.0   6.123712  21.696074
# 57      M S                 Leeds   6.0   6.219143  16.792778
#
#              xGBuildup;
# 0    4.451256847940385;
# 1    9.800235655158758;
# 2    11.93228487111628;
# 3    6.608751138672233;
# 4    4.131795546039939;
# 5    4.159406214952469;
# 6     2.41258773393929;
# 7   5.3349911738187075;
# 8   10.148374736309052;
# 9   2.9379407837986946;
# 10  1.0525451973080635;
# 11  3.4299153089523315;
# 12  2.0632555447518826;
# 13  2.1498517598956823;
# 14  3.6344361882656813;
# 15   8.927207557484508;
# 16   6.057656282559037;
# 17  2.5945137250237167;
# 18    3.75792377255857;
# 19   3.955129318870604;
# 20  2.6550637893378735;
# 21   3.153553775511682;
# 22  11.477124504745007;
# 23   2.730645166710019;
# 24  2.6913463715463877;
# 25   8.610449083149433;
# 26  10.198550110682845;
# 27   5.617282949388027;
# 28   9.019599789753556;
# 29  1.5948405284434557;
# 30  4.0760964918881655;
# 31  2.7446243297308683;
# 32   8.928798945620656;
# 33  3.0969949951395392;
# 34   3.381784765049815;
# 35   5.563634850084782;
# 36   4.217725777998567;
# 37   5.408362489193678;
# 39   6.073130352422595;
# 40  13.809802262112498;
# 41   8.035575423389673;
# 42  1.3322140527889132;
# 43   10.87897537369281;
# 44  4.3486531134694815;
# 45  5.1744528617709875;
# 46  2.7242567520588636;
# 47   5.954058945178986;
# 48  3.1875317404046655;
# 49   5.242121719755232;
# 50   1.476512636989355;
# 51   6.972043983638287;
# 52  2.1223282255232334;
# 53   3.660514172166586;
# 54   7.104181377217174;
# 55   14.94546852633357;
# 56  12.443149040453136;
# 57   6.679691860452294;

# %%
# 10 Player terbanyak mencetak gol
top_10_scorers = df.nlargest(10, 'goals')
plt.figure(figsize=(10, 6))
plt.bar(top_10_scorers['player_name'], top_10_scorers['goals'], color='gray')
plt.title('Top 10 Goal Scorers')
plt.xlabel('Players')
plt.ylabel('goals')
plt.xticks(rotation=45)
plt.show()

# %%
# 10 player terlama durasi bermain
top_10_playing_time = df.nlargest(10, 'time')
plt.figure(figsize=(10, 6))
plt.bar(top_10_playing_time['player_name'], top_10_playing_time['time'], color='red')
plt.title('Top 10 Longest Playing Time')
plt.xlabel('Players')
plt.ylabel('Minutes Played')
plt.xticks(rotation=45)
plt.show()

# %%
# 10 player terbanyak assist
top_10_assists = df.nlargest(10, 'assists')
plt.figure(figsize=(10, 6))
plt.bar(top_10_assists['player_name'], top_10_assists['assists'], color='blue')
plt.title('Top 10 Assists Providers')
plt.xlabel('Players')
plt.ylabel('assists')
plt.xticks(rotation=45)
plt.show()

# %%
# 4 player pencetak gol terbanyak dari kesebelasan Manchester City
man_city_top_scorers = df[df['team_title'] == 'Manchester City'].nlargest(4, 'goals')
plt.figure(figsize=(8, 5))
plt.bar(man_city_top_scorers['player_name'], man_city_top_scorers['goals'], color='purple')
plt.title('Top 4 Goal Scorers from Manchester City')
plt.xlabel('Players')
plt.ylabel('goals')
plt.xticks(rotation=45)
plt.show()

# %%
# Dari kesebelasan mana pencetak gol terbanyak
team_most_goals = df.groupby('team_title')['goals'].sum().idxmax()
print("Team with most goals:", team_most_goals)
# Out:
# Team with most goals: Manchester City

# %%
# Berapa jumlah kartu kuning dan merah yang diterima oleh pembuat assist terbanyak
top_assist_provider = df.sort_values(by='assists', ascending=False).iloc[0]
yellow_cards = top_assist_provider['yellow_cards']
red_cards = top_assist_provider['red_cards']
print("Yellow cards received by top assist provider:", yellow_cards)
print("Red cards received by top assist provider:", red_cards)
# Out:
# Yellow cards received by top assist provider: 1.0
# Red cards received by top assist provider: 0.0

# %%
# Siapa yang jumlah assist dan golnya paling banyak dan dari kesebelasan mana
# Temukan pemain dengan total poin maksimum
player_with_max_points = df['player_name'].loc[df['goals'].idxmax()]
team_of_max_points = df['team_title'].loc[df['assists'].idxmax()]

# Cetak hasil
print("Pemain dengan total gol dan assist terbanyak:", player_with_max_points)
print("Kesebelasan pemain dengan total gol dan assist terbanyak:", team_of_max_points)
# Out:
# Pemain dengan total gol dan assist terbanyak: Harry Kane
# Kesebelasan pemain dengan total gol dan assist terbanyak: Tottenham

# %%
# 5 kesebelasan yang menyumbangkan gol terbanyak
sorted_team_goals = team_goals.sort_values(ascending=False)
print("5 Kesebelasan dengan Total Gol Terbanyak:")
print(sorted_team_goals.head(5))
# Out:
# 5 Kesebelasan dengan Total Gol Terbanyak:
# team_title
# Manchester City      77.0
# Manchester United    68.0
# Tottenham            66.0
# Liverpool            64.0
# Leicester            64.0
# Name: goals, dtype: float64

# %%
# Urutkan pemain berdasarkan jumlah gol terbanyak tanpa mendapatkan kartu sama sekali
players_cards = df[(df['yellow_cards'] == 0) & (df['red_cards'] == 0)].sort_values(by='goals', ascending=False)
print("Players with most goals without receiving any cards:")
print(players_cards[['player_name', 'goals']])
# Out:
# Players with most goals without receiving any cards:
#           player_name  goals
# 1       Mohamed Salah   22.0
# 3       Son Heung-Min   17.0
# 13         Chris Wood   12.0
# 28       Riyad Mahrez    9.0
# 29      Harvey Barnes    9.0
# ..                ...    ...
# 348  Shkodran Mustafi    0.0
# 343     Islam Slimani    0.0
# 341        Moise Kean    0.0
# 340           Emerson    0.0
# 521   Tyrese Francois    0.0
#
# [162 rows x 2 columns]
